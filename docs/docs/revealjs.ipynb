# %% [markdown]
# # Make slides using JupyterLab

# %% [markdown]
# ## Set Slide Type

# %%
from IPython.display import Image

# %%
Image("../images/cell-tools-ipynb.png")

# %% [markdown]
# ## Export Reveal.js Slides

# %%
Image("../images/revealjs-ipynb.png")

# %%
def numgen(n):  
    num = 0
    while num < n:
        yield num
        num += 1

# %%
sum(1 for _ in numgen(100_000))
# Out:
# 100000

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')
g = sns.pairplot(iris, hue="species", markers=["o", "s", "D"], size=2)
plt.savefig("scatplt.png")
